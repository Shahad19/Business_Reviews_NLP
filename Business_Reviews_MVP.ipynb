# %% [markdown]
# # Business Review Sentiment Analysis

# %% [markdown]
# According to the project proposal, in order to be able to categorize the reviews as positive or negative or Neutral , the reviews must first be pre-processed.
#
# After cleaning the text data (reviews) and applying NLP techniques. The figures below show the most common words used in positive and negative reviews, as well as natural words without overlap

# %% [markdown]
# ![reviews.jpg](attachment:reviews.jpg)

# %% [markdown]
# Now data is ready to be used in classification models to predict the sentiments.
